# %% [markdown]
# ![image.png](attachment:97b860f9-ea04-4b86-8cc1-731d02044670.png)

# %% [markdown]
# ![image.png](attachment:cafb10af-2309-449c-b3d8-b18101372e4f.png)

# %% [markdown]
# ![image.png](attachment:1421bf65-88b2-4eab-8178-127e24496210.png)

# %% [markdown]
# ![image.png](attachment:94970f87-3306-4e10-a3e8-82e27d4265fd.png)

# %% [markdown]
# ![image.png](attachment:6bcef748-2dbe-48d4-af96-5a158420dec8.png)

# %% [markdown]
# ![image.png](attachment:b0e336b3-085d-4c3c-891f-ff3ba1d2c9fb.png)

# %% [markdown]
# ![image.png](attachment:ffa49828-7cbf-410e-9343-2cce28ed2232.png)

# %% [markdown]
# ![image.png](attachment:037dedac-414a-48e4-bad8-84f733bc7abb.png)

# %% [markdown]
# ![image.png](attachment:11dac63a-d51c-4635-86b3-fc993a311729.png)

# %% [markdown]
# ![image.png](attachment:35f0bb51-4015-4c5d-b273-4e140a571be4.png)

# %% [markdown]
# ![image.png](attachment:59e5bf8a-f719-468f-8d4b-8cd70340e693.png)

# %% [markdown]
# ![image.png](attachment:33d81bbe-b230-4aed-8b53-4eec0580facd.png)

# %% [markdown]
# ![image.png](attachment:9b138e46-bed9-442d-9703-18df2318a837.png)
