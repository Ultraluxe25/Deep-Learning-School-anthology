# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Распределение СВ - вероятность того что СВ равна тому или иному значению.

# %% [markdown]
# ### Биннинг
# ![image.png](attachment:image.png)

# %% [markdown]
# Выборка - набор данных для эксперимента (часть ГС - генеральной совокупности)

# %% [markdown]
# Для выборки важно независимость её элементов друг от друга
