# %% [markdown]
# ![image.png](attachment:73ed0313-ea19-4f1a-b315-5cafe3758176.png)

# %% [markdown]
# ![image.png](attachment:481546e0-e1fe-48b2-9af6-b0105b3175ac.png)

# %% [markdown]
# ![image.png](attachment:bfe0ee70-bdb4-429a-ab7c-448634189a6e.png)

# %% [markdown]
# ![image.png](attachment:0077e0ee-653b-47ae-a43b-ddcd136156bc.png)

# %%
import numpy as np

mat = np.matrix(data='3, 8; 2, 6')
mat
# Out:
# matrix([[3, 8],
#         [2, 6]])

# %% [markdown]
# ![image.png](attachment:4cb1a98c-0280-4654-a1ad-03e12baebd07.png)

# %% [markdown]
# ![image.png](attachment:b3effbf7-aa3c-4ec5-84b8-215d8e92f1c1.png)

# %% [markdown]
# ![image.png](attachment:da5e3717-c4b7-4b68-afd9-4c5802c00bb7.png)

# %% [markdown]
# ![image.png](attachment:b500c527-9ef0-460e-85bd-820a5ba402da.png)

# %% [markdown]
# ![image.png](attachment:5cb7686f-4b8a-4478-968d-74c5e9952d35.png)
