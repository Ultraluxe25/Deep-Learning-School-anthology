# %% [markdown]
# ![image.png](attachment:3706df43-d3bc-416d-b0ce-23f68baabb80.png)

# %% [markdown]
# ![image.png](attachment:598aeeb1-2537-4e21-bae9-0f6215299865.png)

# %% [markdown]
# ![image.png](attachment:abca64eb-d156-459b-842e-de6a84dc5689.png)

# %% [markdown]
# ![image.png](attachment:b47d1aa8-c21e-4b4d-989d-e2136e9ae857.png)

# %% [markdown]
# ![image.png](attachment:1c19dff1-fc6f-4db9-b522-8eb9ce4e4cf5.png)

# %% [markdown]
# ![image.png](attachment:c94efd64-2d1d-476f-a47e-35b6c55501c6.png)

# %% [markdown]
# ![image.png](attachment:df203d51-2600-4d92-b6b7-ea5f6e1d8e8c.png)

# %% [markdown]
# ![image.png](attachment:4fe41584-79c5-4b69-850a-cea92fd35bc4.png)

# %% [markdown]
# ![image.png](attachment:1057840d-bc76-4b8f-829d-ee8ddcbeee44.png)
