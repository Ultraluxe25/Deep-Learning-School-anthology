# %% [markdown]
# ![image.png](attachment:86f3e9f2-f2ff-48d0-99d3-e4beee1f239b.png)

# %% [markdown]
# ![image.png](attachment:a56ca256-753a-4705-8d6a-2efad242d0f7.png)

# %% [markdown]
# ![image.png](attachment:826cbf24-9783-4ce6-8041-8091d4c0844d.png)

# %% [markdown]
# # Планируется сделать отдельный 3-й семестр по работе с Аудио

# %% [markdown]
# ### В некоторых домашках нужно изучить код трех других студентов

# %% [markdown]
# ![image.png](attachment:34da1c50-22f7-4a80-8f01-eb9e0f762cf3.png)

# %% [markdown]
# ![image.png](attachment:f397a93d-48f1-4377-a1b1-5f19f292f100.png)

# %% [markdown]
# ![image.png](attachment:33e5ef72-660b-4665-8810-c1fe5f6eaf96.png)

# %% [markdown]
# ### Для диплома первой степени можно не сделать одну домашку или набрать ~90% баллов

# %% [markdown]
# ### Чтобы сдать проект по нему нужно набрать 50%+ баллов (5 из 10)

# %% [markdown]
# ![image.png](attachment:3c6dc34c-eb85-4ac5-b850-1feddef84f23.png)
