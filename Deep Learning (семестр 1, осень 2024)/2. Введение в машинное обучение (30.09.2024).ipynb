# %% [markdown]
# ![image.png](attachment:1e5342aa-daf8-4dcd-93aa-219c7cc0047f.png)

# %% [markdown]
# ![image.png](attachment:c4b0b649-3a3a-4217-8760-fc6192799a71.png)

# %% [markdown]
# ### KNN может быть классификатором и регрессором

# %% [markdown]
# ### Проклятье размерности в том, что с увеличением размерности признакового пространства не только выростает вычислительная сложность алгоритма, но и классификатору труднее определиться к какому классу при разных гиперпараметрах все таки отнести каждое из новых наблюдений на тестовой выборке

# %% [markdown]
# ![image.png](attachment:fabe75bf-217e-4d2d-88f5-042fcf5e69e2.png)

# %% [markdown]
# ![image.png](attachment:5e81be49-de0f-4e54-bac5-5f907a3e199b.png)

# %% [markdown]
# ![image.png](attachment:1583570f-0d9d-4623-a555-22d809893072.png)
# ### Полиномы 1, 2 и 300-й степени

# %% [markdown]
# ![image.png](attachment:677444d5-2668-47c4-b8fc-db7b1cb833a1.png)
# ### Cross-валидация позволяет все данные прогнать в обучение и лучше чем простое разбитие на тренировочную и валидационную

# %% [markdown]
# ### Т.к нейронки обучаются от нескольких часов до нескольких месяцев, в них почти никогда не делается кросс-валидация, потому что придется k раз обучать модель

# %% [markdown]
# ![image.png](attachment:308abc3c-9dca-4673-b1ee-c0292c39645d.png)
